# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
resumes = [
    "Python SQL Machine Learning Data Analysis",
    "Java Spring Boot MySQL",
    "Python Machine Learning Deep Learning NLP",
    "Excel Power BI SQL Data Analytics",
    "Python Pandas NumPy Scikit Learn"
]

candidates = [
    "Candidate A",
    "Candidate B",
    "Candidate C",
    "Candidate D",
    "Candidate E"
]

# %%
job_description = """
Python Machine Learning SQL Data Analysis
"""

# %%
documents = [job_description] + resumes

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

# %%
scores = cosine_similarity(
    tfidf_matrix[0:1],
    tfidf_matrix[1:]
)

scores = scores.flatten()

# %%
results = pd.DataFrame({
    "Candidate": candidates,
    "Match Score": scores
})

results = results.sort_values(
    by="Match Score",
    ascending=False
)

print(results)
# Out:
#      Candidate  Match Score
# 0  Candidate A     1.000000
# 2  Candidate C     0.478907
# 3  Candidate D     0.250995
# 4  Candidate E     0.098369
# 1  Candidate B     0.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.bar(
    results["Candidate"],
    results["Match Score"]
)

plt.title("Candidate Ranking")

plt.xlabel("Candidates")
plt.ylabel("Match Score")

plt.show()

# %%
required_skills = {
    "Python",
    "SQL",
    "Machine Learning",
    "Data Analysis"
}

candidate_resume = resumes[1]

candidate_skills = set(candidate_resume.split())

missing = required_skills - candidate_skills

print("Missing Skills:")
print(missing)
# Out:
# Missing Skills:
# {'SQL', 'Python', 'Machine Learning', 'Data Analysis'}

# %%
top_candidate = results.iloc[0]

print(
    "Best Candidate:",
    top_candidate["Candidate"]
)

print(
    "Match Score:",
    round(top_candidate["Match Score"],2)
)
# Out:
# Best Candidate: Candidate A
# Match Score: 1.0
